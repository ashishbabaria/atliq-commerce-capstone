# %%
# %sql
CREATE CATALOG IF NOT EXISTS atliq
MANAGED LOCATION 'abfss://lakehouse@atliqlakeab.dfs.core.windows.net/';

CREATE SCHEMA IF NOT EXISTS atliq.silver;
CREATE SCHEMA IF NOT EXISTS atliq.gold;

# %% [markdown]
# ### Bronze read test

# %%
df = spark.read.parquet("abfss://lakehouse@atliqlakeab.dfs.core.windows.net/bronze/customers")
print("bronze customers rows:", df.count())
display(df.limit(5))
